# %%
import pickle 
with open("paths.pickle", "rb") as f:
    paths = pickle.load(f)

# %%
paths[7]
# Out:
# {'attributes': {'depth': 3,
#   'precursor_cost': 45.0,
#   'score': None,
#   'cluster_id': None},
#  'smiles': 'COc1cc(Nc2ncc(F)c(Nc3ccc4c(n3)NC(=O)C(C)(C)O4)n2)cc(OC)c1OC',
#  'ppg': 0.0,
#  'as_reactant': 14,
#  'as_product': 16,
#  'properties': None,
#  'terminal': False,
#  'is_chemical': True,
#  'id': '00000000-0000-0000-0000-000000000000',
#  'children': [{'smiles': 'CC1(C)Oc2ccc(N)nc2NC1=O.COc1cc(Nc2ncc(F)c(Br)n2)cc(OC)c1OC>>COc1cc(Nc2ncc(F)c(Nc3ccc4c(n3)NC(=O)C(C)(C)O4)n2)cc(OC)c1OC',
#    'tforms': ['5e1f4b6e63488328509963a2'],
#    'tsources': ['reaxys'],
#    'template_score': 0.0376371294260025,
#    'plausibility': 0.9996411800384521,
#    'is_reaction': True,
#    'rank': 5,
#    'num_examples': 580,
#    'necessary_reagent': '',
#    'precursor_smiles': 'CC1(C)Oc2ccc(N)nc2NC1=O.COc1cc(Nc2ncc(F)c(Br)n2)cc(OC)c1OC',
#    'rms_molwt': 287.001517787918,
#    'num_rings': 4,
#    'scscore': 2.9865594108242264,
#    'id': '320f2141-be33-482e-afa6-54c2ca6f6728',
# ...
